# %% [markdown]
# # First, let's visualize the moon dataset:

# %%
from IPython.display import Image
from IPython.display import display
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl


# inline plotting instead of popping out
# %matplotlib inline

# load utility classes/functions that has been taught in previous labs
# e.g., plot_decision_regions()
import os, sys
module_path = os.path.abspath(os.path.join('.'))
sys.path.append(module_path)
from sklearn import neighbors
from sklearn.datasets import make_moons


X, y = make_moons(
    n_samples=500,  # the number of observations
    random_state=1,
    noise=0.3
)
plt.scatter(X[y == 0, 0], X[y == 0, 1],
            c='r', marker='o', label='Class 0')
plt.scatter(X[y == 1, 0], X[y == 1, 1],
            c='b', marker='s', label='Class 1')


plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.show()

h = .02 # step size in the mesh
knn=neighbors.KNeighborsClassifier(n_neighbors=3)
knn.fit(X, y)

# Plot the decision boundary. For that, we will asign a color to each
# point in the mesh [x_min, m_max]x[y_min, y_max].
x_min, x_max = X[:,0].min() - .5, X[:,0].max() + .5
y_min, y_max = X[:,1].min() - .5, X[:,1].max() + .5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
pl.figure(1, figsize=(8, 6))
pl.set_cmap(pl.cm.Paired)
pl.pcolormesh(xx, yy, Z)

# Plot also the training points
pl.scatter(X[:,0], X[:,1],c=y )
pl.xlabel('x1')
pl.ylabel('x2')

pl.xlim(xx.min(), xx.max())
pl.ylim(yy.min(), yy.max())
pl.xticks(())
pl.yticks(())

pl.show()

knn=neighbors.KNeighborsClassifier(n_neighbors=200)
knn.fit(X, y)

# Plot the decision boundary. For that, we will asign a color to each
# point in the mesh [x_min, m_max]x[y_min, y_max].
x_min, x_max = X[:,0].min() - .5, X[:,0].max() + .5
y_min, y_max = X[:,1].min() - .5, X[:,1].max() + .5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
pl.figure(1, figsize=(8, 6))
pl.set_cmap(pl.cm.Paired)
pl.pcolormesh(xx, yy, Z)

# Plot also the training points
pl.scatter(X[:,0], X[:,1],c=y )
pl.xlabel('x1')
pl.ylabel('x2')

pl.xlim(xx.min(), xx.max())
pl.ylim(yy.min(), yy.max())
pl.xticks(())
pl.yticks(())

pl.show()

# %% [markdown]
# # Change the value of K, show the error for a variety of K, more is better...
# Choose a very small value of K.
#     Do you "see" low variance or high variance?
#     Do you "see" low bias or high bias?

# %% [markdown]
# # Is this a regression or classification problem? Conceptually, how is KNN being applied to this problem to make a prediction?

# %% [markdown]
# This is a classification problem. We are using KNN to classify the data into separate groups. KNN is being used to see if, by understanding how the data is segregated in the training set, we can predict how the data in testing set should be segregated.

# %% [markdown]
# ## What predictions would an ideal machine learning model make, with respect to a descision boundary?

# %% [markdown]
# Ideally, there would be no misclassified data and no unclassified data.

# %% [markdown]
# # Repeat this with a very large value of K.
# 	Do you "see" low variance or high variance?
# 	Do you "see" low bias or high bias?

# %% [markdown]
# # Try using other values of K.
# What value of K do you think is "best"? Evaluate as many K as possable 10+.
# How do you define "best"?

# %% [markdown]
# # Why should we care about variance at all?

# %% [markdown]
# # Shouldn't we just minimize bias and ignore variance?

# %% [markdown]
# # Does a high value for K cause "overfitting" or "underfitting"?

# %% [markdown]
# # Bonus -> Make those fancy plots I had in class, with the decision boundary shown, along with the points and thier respect classes shown by way of different colors.
